# %% [markdown]
# This telco-customer-churn dataset contains 7044 rows and 21 coloumns. Churn analysis is basically done to know the reason that why a particular company is loosing its customer. so that the company can reduce that rate. Churn analysis helps you identify pain points throughout the entire customer journey

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv('/Users/hailing/Downloads/7_Exercise_Matplotlib_Seaborn/7_WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %% [markdown]
# **Q-1** Mention the first five entries of the above mentioned data set.

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# **Q-2** Using seaborn library, plot the graph between churn and count of churn.

# %%
sns.countplot(data=df, x='Churn', order=df.Churn.value_counts().index)
plt.title('Churn vs Count of churn')
plt.xlabel('Churn')
plt.ylabel('Count of Churn')
# Out:
# Text(0, 0.5, 'Count of Churn')

# %% [markdown]
# **Q-3** Plot the scatter graph to show the relationship between tenure & Monthly charges

# %%
plt.xlabel('Tenure')
plt.ylabel('Monthly Charges')
plt.title('Tenure vs Monthly Charges')
plt.scatter(df['tenure'], df['MonthlyCharges'])

# %% [markdown]
# **Q-4** Write the total number of rows and coloumn in the given data set.

# %%
print(df.shape)
# Out:
# (7043, 21)

# %% [markdown]
# **Q-5** Write the code for getting the summary statistics of the numerical columns?

# %%
summary_stats = df.describe()
summary_stats
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# **Q-6** Plot the bargraph between Count of target variable per category.

# %%
plt.xlabel('Churn')
plt.ylabel('Count')
plt.title('Count of Churn per Category')

sns.countplot(x='Churn', data=df)

# %% [markdown]
# **Q-7** Plot the graph between monthly charges and total charges.

# %%
#I have reduced the values by using .ylim cos the original scatter plot contains too many values and it looks too messy

plt.ylim(0, 50)
plt.scatter(df['MonthlyCharges'], df['TotalCharges'])
plt.xlabel('Monthly Charges')
plt.ylabel('Total Charges')
plt.title('Monthly Charges vs Total Charges')
# Out:
# Text(0.5, 1.0, 'Monthly Charges vs Total Charges')

# %%
plt.ylim(0, 400)
plt.xlabel('Monthly Charges')
plt.ylabel('Total Charges')
plt.title('Monthly Charges vs Total Charges')
sns.lineplot(x=df['MonthlyCharges'], y=df['TotalCharges'])
# Out:
# <Axes: title={'center': 'Monthly Charges vs Total Charges'}, xlabel='Monthly Charges', ylabel='Total Charges'>

# %% [markdown]
# **Q-8** check the distribution of the target varible (i.e churn )

# %%
plt.xlabel('Churn')
plt.ylabel('Count')
plt.title('Distribution of Target Variable')
sns.countplot(data=df, x='Churn')
# Out:
# <Axes: title={'center': 'Distribution of Target Variable'}, xlabel='Churn', ylabel='count'>

# %% [markdown]
# **Q-9** Plot the scatter graph between total charges and monthly charges.

# %%
plt.xlabel('TotalCharges')
plt.ylabel('MonthlyCharges')
plt.title('Total Charges vs Monthly Charges')
plt.scatter(df['TotalCharges'], df['MonthlyCharges'])

# %% [markdown]
# **Q-10** Plot the join plot between total charges and monthly charges. (Use seaborn.jointplot)

# %%
sns.jointplot(data=df, x='TotalCharges', y='MonthlyCharges',height=5, ratio=2, marginal_ticks=True)

# %% [markdown]
# **Q-11** Total Charges should be numeric amount. Let's convert it to numerical data type and check whether it has any null values or not.

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'],errors='coerce')
null_values=df['TotalCharges'].isnull().sum()
print('Null Values:',null_values)

df.describe()
# Out:
# Null Values: 11
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# **Q-12** As we can see there are 11 missing values in TotalCharges column. Let's check these records

# %%
missing_values=df[df['TotalCharges'].isnull()]
missing_values
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# **Q-13** Convert the target variable 'Churn' in a binary numeric variable i.e. Yes=1 ; No = 0

# %%
df['Churn'] = df['Churn'].replace({'Yes': 1, 'No': 0})

df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %% [markdown]
# **Q-14** Build a corelation of all predictors with 'Churn' and plot a bar chart (Use dataframe.corr() function)

# %%
newdf=df.corr()
newdf['Churn']
# Out:
# /var/folders/s2/r5xn6dmj38v0rrs7t53585bc0000gn/T/ipykernel_22421/1389206409.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   newdf=df.corr()
# SeniorCitizen     0.150889
# tenure           -0.352229
# MonthlyCharges    0.193356
# TotalCharges     -0.199484
# Churn             1.000000
# Name: Churn, dtype: float64

# %%
corr_asc = newdf['Churn'].sort_values(ascending=False)
plt.xlabel('Predictors')
plt.ylabel('Correlation with Churn')
plt.title('Correlation of Predictors with Churn')

sns.barplot(x=corr_asc.index, y=corr_asc.values)
# Out:
# <Axes: title={'center': 'Correlation of Predictors with Churn'}, xlabel='Predictors', ylabel='Correlation with Churn'>

# %% [markdown]
# **Q-15** Plot a pie chart showing the distribution of the Payment Methods

# %%
plt.title("Distribution of the Payment Methods")
df['PaymentMethod'].value_counts().plot(kind='pie', figsize=(10, 5),autopct='%.0f%%')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

# %% [markdown]
# **Q-16** Plot a line chart showing the distribution of tenure

# %%
plt.xlabel('Tenure')
plt.ylabel('Count of tenure')
plt.title('Distribution of Tenure')

tenure_count = df['tenure'].value_counts().sort_index()
sns.lineplot(x=tenure_count.index, y=tenure_count.values)
# Out:
# <Axes: title={'center': 'Distribution of Tenure'}, xlabel='Tenure', ylabel='Count of tenure'>

# %% [markdown]
# **Q-17** Plot an area chart showing the distribution of tenure

# %%
plt.xlabel('Tenure')
plt.ylabel('Count of tenure')
plt.title('Distribution of Tenure')

tenure_count = df['tenure'].value_counts().sort_index()
plt.fill_between(tenure_count.index, tenure_count.values)
